# %% [markdown]
# ## โจทย์เรื่องการตั้งค่า Operator
# จงเขียนลำดับการคำนวณของนิพจน์ต่อไปนี้

# %% [markdown]
# ## ตัวอย่าง
# 2 ** 3 + 5 * 7 - 9

# %%
2**3  + 5*7 - 9
  8   + 5*7 - 9
  8   + 35  - 9
    43      - 9
            34

# %% [markdown]
# 1.) 2 ** 3 + 5 * 7 - 9

# %% [markdown]
# 2.) 5 * 2 ** 3 + 4 * 5

# %% [markdown]
# 3.) 2 ** 3 ** 2

# %% [markdown]
# 4.) 5 + 4 + 3 + 2 + 1

# %% [markdown]
# 5.) 7 % 2 ** 2

# %% [markdown]
# 6.) 7 // (3 ** 2 ** 2 - 75)

# %% [markdown]
# 7.) 6 % 7 // 3 + 2 ** 3

# %% [markdown]
# 8.) 5 ** 2 // (2 * 2 + 4)

# %% [markdown]
# 9.) 1 + 2 ** 3 * 1 - 1/2

# %% [markdown]
# 10.) (1 + 2) + (3 * 4) - (2 ** 3)

# %% [markdown]
# 11.) y = 2 ** 2

# %% [markdown]
# 12.) y = 3 ** 2/2 ** 3

# %% [markdown]
# 13.) y = 2 ** 4 ** 1/2

# %% [markdown]
# 14.) y = 2 * (4 ** 2) % (8 // 2)

# %% [markdown]
# 15.) y = 2 * 4 - 15 >= 1

# %% [markdown]
# #จงวาด flowchart และเขียน code ของโจทย์ต่อไปนี้

# %% [markdown]
# ## 1. เขียนโปรแกรมพิมพ์ 0, 1, 2, ..., 19 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 2.เขียนโปรแกรมพิมพ์ 0, 2, 4,...., 18 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 3. เขียนโปรแกรมพิมพ์ 1, 3, 5, ..., 19 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 4.เขียนโปรแกรมพิมพ์ 19, 18, 17 ...., 0 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 5. เขียนโปรแกรมพิมพ์ 18, 16, 14 ,... , 0 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 6. เขียนโปรแกรมพิมพ์ 19, 17, 15, ..., 1 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 7. เขียนโปรแกรมพิมพ์ -3, -2, -1 , 0 , ... ,9 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 8. เขียนโปรแกรมพิมพ์ -9, 8, -7 ,.... 0 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 9.เขียนโปรแกรมพิมพ์ -5, -6, -7 , ... , -15 โดยการใช้ for Ioop หรือ while loop

# %% [markdown]
# ## 10. เขียนโปรแกรมพิมพ์ -5, - 7, -9,...., - 15 โดยการใช้ for loop หรือ while loop

# %% [markdown]
# ## 11. เขียนโปรแกรมรับค่า n แล้วคำนวณค่าต่อไปนี้ และพิมพ์ออกมา
# > 1+2+3+...+n

# %% [markdown]
# ## 12. เขียนโปรแกรมรับค่า n แล้วคำนวณค่าต่อไปนี้ และพิมพ์ออกมา
# > 1x2x3x...xn

# %% [markdown]
# ## 13.  เขียนโปรแกรมรับค่า n แล้วคำนวณค่าต่อไปนี้ และพิมพ์ออกมา
# > 1/1 + 1/2 + 1/3 ... +  1/n

# %% [markdown]
# ## 14. เขียนโปรแกรมรับค่า n แล้วคำนวณค่าต่อไปนี้ และพิมพ์ออกมา
# > 1/(1^2) + 1/(2^2) + 1/(3^2) ... + 1/(n^2)

# %% [markdown]
# ## 15. เขียนโปรแกรมรับค่า n แล้วคำนวณค่าต่อไปนี้ และพิมพ์ออกมา
# > sqrt(6x(1/(1^2) + 1/(2^2) + 1/(3^2) ... + 1/(n^2))

# %% [markdown]
# ## โจทย์เรื่องการใช้ print()
# จงเขียนโปรแกรมที่จะเเสดงผลลัพธ์ตามโจทย์

# %% [markdown]
# ### การใช้ Function Print กับ String

# %% [markdown]
# 1. > Hello World

# %% [markdown]
# 2. > Hello_Python

# %% [markdown]
# 3. > Hello 😘
#
# <br>hint: ตัว 😘 เรียกว่า emoticon สามารถพิมพ์จากวินโดว์11 ได้เลย

# %% [markdown]
# 4. > Merry X'Mas

# %% [markdown]
# 5. > I want to ask you "Why don't you drive to work ?"

# %% [markdown]
# 6. > "I don't have a car"

# %% [markdown]
# 7. > ก็มาดิค้าบ

# %% [markdown]
# 8. > เธอบอกว่า "เราเป็นได้แค่พี่น้อง"

# %% [markdown]
# 9. > a<br>an<br>the

# %% [markdown]
# 10. > /\\/\\/\\

# %% [markdown]
# 11. >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*&nbsp;&nbsp;&nbsp;&nbsp;<br>
# >\*&nbsp;&nbsp;&nbsp;&nbsp;\*&nbsp;&nbsp;&nbsp;&nbsp;\*<br>
# >&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*&nbsp;&nbsp;&nbsp;&nbsp;<br>

# %% [markdown]
# 12. > \*\*\*\*\*<br>
# >\*&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*<br>
# >\*&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*<br>
# >\*&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*<br>
# > \*\*\*\*\*<br>

# %% [markdown]
# 13. > \*\*\*\*\*<br>
# >\*&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*<br>
# >\*&nbsp;&nbsp;\*&nbsp;&nbsp;\*<br>
# >\*&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\*<br>
# > \*\*\*\*\*<br>

# %% [markdown]
# 14. > ( ಠ ͜ʖ ಠ )<br>
# >/|&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|><br>
# >&nbsp;&nbsp;&nbsp;&nbsp;T&nbsp;&nbsp;T

# %% [markdown]
# 15. >Thy love is such I can no way repay;<br>
# The heavens reward thee manifold, I pray.<br>
# Then while we live, in love let’s so persever,<br>
# That when we live no more, we may live ever.

# %% [markdown]
# ### การใช้ Function Print กับ Numeric

# %% [markdown]
# 16. >25

# %% [markdown]
# 17. > 100.00000<br>
#
# hint: เราไม่ได้พริ๊นท์ String เราพริ๊นตัวเลข float

# %% [markdown]
# 18. > 3.141592653589793

# %% [markdown]
# ### การใช้ print() รูปแบบ ผสม ทั้ง String และ Numeric

# %% [markdown]
# กำหนดให้ a = 2

# %% [markdown]
# 19. > a = 2

# %% [markdown]
# กำหนดให้  a = 2, b = 5

# %% [markdown]
# 20. > a = 2 <br>
#     > b = 5 <br>
#     > 2 x 5 = 6

# %% [markdown]
# กำหนดให้ a = 2, b = 3, c = 5

# %% [markdown]
# 21. > a = 2<br>
#     > b = 3<br>
#     > c = 5<br>
#     > 2*(3+5) = 2 * 3 + 2 * 5

# %% [markdown]
# กำหนดให้ค่าในตัวแปร day month year
# 22. > ฉันเกิดวันที่ 1 มกราคม 2077

# %% [markdown]
# 23. > ฉันขอแบ่งรายได้ 5%
